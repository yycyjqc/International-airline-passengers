# %%
import pandas as pd
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]

# %%
# load csv file
data_set = pd.read_csv('datasets_1392_2506_international-airline-passengers.csv')
data_set.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
# checking the missing value
data_set.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
# confirm that Month columns is in datetime format
data_set.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
# convert generic object into datetime
data_set['Month'] = pd.to_datetime(data_set['Month'])
data_set.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
# check type
data_set.dtypes
# Out:
# Month          datetime64[ns]
# #Passengers             int64
# dtype: object

# %%
# indexing 
data_set = data_set.set_index('Month')
data_set.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
# plot
data_set.plot(grid=True)

# %% [markdown]
# * An upward trend indicating that the airline would have more passenger over time.
# * Although there are ups and downs at every point in time, generally I can observe that the trend increases.
# * The ups and downs seem to be a bit regular which means I might be ovserving a seasonal pattern.

# %%
# ovserving some year's data
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]
from datetime import datetime
start_date = datetime(1959, 1, 1)
end_date = datetime(1960, 12, 1)
data_set[(start_date <=data_set.index ) & (data_set.index <= end_date)].plot(grid=True)

# %% [markdown]
# * There is usually a spike between July and September which begins to drop by October
# * Which means more people travel between July and September and probably travel less from Octomber

# %% [markdown]
# ### Decomposition of Time Series
# * Additive Model: y(t) = Level(t) + Trend(t) + Seasonality(t) + Noise(t)
# * Multiplicative Model: y(t) = Level(t) * Trend(t) * Seasonality(t) *Noise(t)

# %%
# load tsa(time series analysis) package
import statsmodels.api as sm
decomposition = sm.tsa.seasonal_decompose(data_set, model = 'additive')
fig = decomposition.plot()

# %%
# plot the trend alongside the observed time series
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, ax = plt.subplots()
ax.grid(True)

year = mdates.YearLocator(month=1)
month = mdates.MonthLocator(interval=3)
year_format = mdates.DateFormatter('%Y')
month_format = mdates.DateFormatter('%m')

ax.xaxis.set_minor_locator(month)

ax.xaxis.grid(True, which = 'minor')
ax.xaxis.set_major_locator(year)
ax.xaxis.set_major_formatter(year_format)

plt.plot(data_set.index, data_set['#Passengers'], c='blue')
plt.plot(decomposition.trend.index, decomposition.trend, c='red')
